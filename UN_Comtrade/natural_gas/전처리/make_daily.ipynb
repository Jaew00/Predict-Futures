# %%
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format

# %%
df = pd.read_excel("comtrade_un.xlsx", sheet_name=0)

# %%
df
# Out:
#            Date    NetWeight  TradeValue
# 0    2017-01-01 1056423635.0  49877021.0
# 1    2017-01-02 1056424135.0  49877521.0
# 2    2017-01-03 1056424635.0  49878021.0
# 3    2017-01-04 1056425135.0  49878521.0
# 4    2017-01-05 1056425635.0  49879021.0
# ...         ...          ...         ...
# 1890 2022-03-06          NaN         NaN
# 1891 2022-03-07          NaN         NaN
# 1892 2022-03-08          NaN         NaN
# 1893 2022-03-09          NaN         NaN
# 1894 2022-03-10          NaN         NaN
#
# [1895 rows x 3 columns]

# %%
df1 = pd.read_excel("data.xlsx")

# %%
df1
# Out:
#           기준일    NetWeight  TradeValue
# 0  2017-01-01 1056430635.0  49884021.0
# 1  2017-02-01 1584359440.0  69407366.0
# 2  2017-03-01 2519740328.0 126645811.0
# 3  2017-04-01 3742221776.0 110706568.0
# 4  2017-05-01 4318956731.0 132301154.0
# ..        ...          ...         ...
# 59 2021-12-01  142415000.0   7855992.0
# 60 2022-01-01          NaN         NaN
# 61 2022-02-01          NaN         NaN
# 62 2022-03-01          NaN         NaN
# 63 2022-04-01          NaN         NaN
#
# [64 rows x 3 columns]

# %%
n = len(df['Date'])
n1 = len(df1['기준일'])

# %%
print(n, n1)
# Out:
# 1895 64

# %%
for i in range(n1) :
  if df1['기준일'][i].year == 2017 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2018 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2019 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2020 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2021 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  else :
    pass
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_r1 = df

# %%
df_r1
# Out:
#            Date    NetWeight  TradeValue
# 0    2017-01-01 1056430635.0  49884021.0
# 1    2017-01-02 1056430635.0  49884021.0
# 2    2017-01-03 1056430635.0  49884021.0
# 3    2017-01-04 1056430635.0  49884021.0
# 4    2017-01-05 1056430635.0  49884021.0
# ...         ...          ...         ...
# 1890 2022-03-06          NaN         NaN
# 1891 2022-03-07          NaN         NaN
# 1892 2022-03-08          NaN         NaN
# 1893 2022-03-09          NaN         NaN
# 1894 2022-03-10          NaN         NaN
#
# [1895 rows x 3 columns]

# %%
df2 = pd.read_excel("data.xlsx", sheet_name = 1)

# %%
df2
# Out:
#           기준일   NetWeight  TradeValue
# 0  2011-01-01   779926682   155396452
# 1  2011-02-01   731513284   126055226
# 2  2011-03-01  1048322603   255519823
# 3  2011-04-01  1787970898   172553024
# 4  2011-05-01  1699567778   188648497
# ..        ...         ...         ...
# 67 2016-08-01  4113160494   112906359
# 68 2016-09-01  7057411200   159857608
# 69 2016-10-01  2486104520   111465940
# 70 2016-11-01  1364772453    59284323
# 71 2016-12-01  2559352866   101347398
#
# [72 rows x 3 columns]

# %%
df = pd.read_excel("comtrade_un.xlsx", sheet_name=1)

# %%
df
# Out:
#            Date  NetWeight  TradeValue
# 0    2011-01-01        NaN         NaN
# 1    2011-01-02        NaN         NaN
# 2    2011-01-03        NaN         NaN
# 3    2011-01-04        NaN         NaN
# 4    2011-01-05        NaN         NaN
# ...         ...        ...         ...
# 2187 2016-12-27        NaN         NaN
# 2188 2016-12-28        NaN         NaN
# 2189 2016-12-29        NaN         NaN
# 2190 2016-12-30        NaN         NaN
# 2191 2016-12-31        NaN         NaN
#
# [2192 rows x 3 columns]

# %%
n = len(df['Date'])
n1 = len(df2['기준일'])
print(n, n1)
# Out:
# 2192 72

# %%
for i in range(n1) :
  if df2['기준일'][i].year == 2011 :
    if df2['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df2['기준일'][i].year == 2012 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df2['기준일'][i].year == 2013 :
    if df2['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df2['기준일'][i].year == 2014 :
    if df2['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df2['기준일'][i].year == 2015 :
    if df2['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df2['기준일'][i].year == 2016 :
    if df2['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df2['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df2['NetWeight'][i]
            df['TradeValue'][k] = df2['TradeValue'][i]
          else :
            pass
        else :
          pass
    else:
      pass
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_r2 = df

# %%
df_r2
# Out:
#            Date    NetWeight  TradeValue
# 0    2011-01-01  779926682.0 155396452.0
# 1    2011-01-02  779926682.0 155396452.0
# 2    2011-01-03  779926682.0 155396452.0
# 3    2011-01-04  779926682.0 155396452.0
# 4    2011-01-05  779926682.0 155396452.0
# ...         ...          ...         ...
# 2187 2016-12-27 2559352866.0 101347398.0
# 2188 2016-12-28 2559352866.0 101347398.0
# 2189 2016-12-29 2559352866.0 101347398.0
# 2190 2016-12-30 2559352866.0 101347398.0
# 2191 2016-12-31 2559352866.0 101347398.0
#
# [2192 rows x 3 columns]

# %%
df_total = pd.concat([df_r2, df_r1], ignore_index=True)

# %%
df_total.to_excel("Comtrade_UN_daily.xlsx")

# %% [markdown]
# # NetWeight, TradeValue 통합 코드

# %%
for i in range(n1) :
  if df1['기준일'][i].year == 2011 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2011 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2012 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2012 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2013 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2013 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2014 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2014 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2015 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2015 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2016 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2016 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2017 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2017 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2018 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2018 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2019 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2019 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2020 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2020 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2021 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 5 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 5 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 6 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 6 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 7 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 7 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 8 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 8 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 9 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 9 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 10 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 10 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 11 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 11 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 12 :
      for k in range(n) :
        if df['Date'][k].year == 2021 :
          if df['Date'][k].month == 12 :
            df['NetWeight'][k] = df1['NetWeight'][i]
            df['TradeValue'][k] = df1['TradeValue'][i]
          else :
            pass
        else :
          pass
  elif df1['기준일'][i].year == 2022 :
    if df1['기준일'][i].month == 1 :
      for k in range(n) :
        if df['Date'][k].year == 2022 :
          if df['Date'][k].month == 1 :
            df['NetWeight'][k] = df1['NetWeight'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 2 :
      for k in range(n) :
        if df['Date'][k].year == 2022 :
          if df['Date'][k].month == 2 :
            df['NetWeight'][k] = df1['NetWeight'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 3 :
      for k in range(n) :
        if df['Date'][k].year == 2022 :
          if df['Date'][k].month == 3 :
            df['NetWeight'][k] = df1['NetWeight'][i]
          else :
            pass
        else :
          pass
    elif df1['기준일'][i].month == 4 :
      for k in range(n) :
        if df['Date'][k].year == 2022 :
          if df['Date'][k].month == 4 :
            df['NetWeight'][k] = df1['NetWeight'][i]
          else :
            pass
        else :
          pass
  else :
    pass

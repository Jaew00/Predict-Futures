# %%
import pandas as pd

# %%
raw_df = pd.read_csv("US Wheat Futures Historical Data.csv")

# %%
raw_df
# Out:
#           Date     Price
# 0     2011.1.3    805.25
# 1     2011.1.4       788
# 2     2011.1.5    809.88
# 3     2011.1.6    788.13
# 4     2011.1.7    772.13
# ...        ...       ...
# 3013  2022.6.3  1,040.00
# 3014  2022.6.5  1,061.88
# 3015  2022.6.6  1,093.00
# 3016  2022.6.7  1,071.75
# 3017  2022.6.8  1,075.50
#
# [3018 rows x 2 columns]

# %%
baltic = pd.read_csv('Baltic Dry Index Historical Data.csv')

# %%
baltic
# Out:
#            Date Baltic_Price
# 0      2012.7.4     1,103.00
# 1      2012.7.5     1,138.00
# 2      2012.7.6     1,157.00
# 3      2012.7.9     1,162.00
# 4     2012.7.10     1,160.00
# ...         ...          ...
# 2474  2022.5.30     2,571.00
# 2475  2022.5.31     2,566.00
# 2476   2022.6.1     2,633.00
# 2477   2022.6.6     2,560.00
# 2478   2022.6.7     2,514.00
#
# [2479 rows x 2 columns]

# %%
df_total = pd.merge(raw_df, baltic, on = "Date", how = "outer")

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3055 entries, 0 to 3054
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          3055 non-null   object
#  1   Price         3018 non-null   object
#  2   Baltic_Price  2479 non-null   object
# dtypes: object(3)
# memory usage: 95.5+ KB

# %%
df_year2 = pd.read_csv("2year_bond.csv")

# %%
df_year2
# Out:
#            Date   Price    Open    High    Low  Change %
# 0      2011.1.3  0.6010  0.6010  0.6010  0.601   -0.0066
# 1      2011.1.4  0.6210  0.6210  0.6210  0.621    0.0333
# 2      2011.1.5  0.7080  0.7080  0.7080  0.708    0.1401
# 3      2011.1.6  0.6770  0.6770  0.6770  0.677   -0.0438
# 4      2011.1.7  0.5970  0.5970  0.5970  0.597   -0.1182
# ...         ...     ...     ...     ...    ...       ...
# 3374   2022.3.7  1.5563  1.4260  1.5640  1.422    0.0901
# 3375   2022.3.8  1.6008  1.5540  1.6410  1.552    0.0286
# 3376   2022.3.9  1.6757  1.6150  1.6880  1.593    0.0468
# 3377  2022.3.10  1.7024  1.6820  1.7350  1.650    0.0159
# 3378  2022.3.11  1.7011  1.6963  1.7072  1.678   -0.0008
#
# [3379 rows x 6 columns]

# %%
df_year2.columns = ["Date", "Y2_Price", "Y2_Open", 'Y2_High', 'Y2_Low', 'Y2_Change']

# %%
df_total = pd.merge(df_total, df_year2, on = "Date", how = "outer")

# %%
df_total
# Out:
#            Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0      2011.1.3  805.25          NaN    0.6010   0.6010   0.6010  0.6010
# 1      2011.1.4     788          NaN    0.6210   0.6210   0.6210  0.6210
# 2      2011.1.5  809.88          NaN    0.7080   0.7080   0.7080  0.7080
# 3      2011.1.6  788.13          NaN    0.6770   0.6770   0.6770  0.6770
# 4      2011.1.7  772.13          NaN    0.5970   0.5970   0.5970  0.5970
# ...         ...     ...          ...       ...      ...      ...     ...
# 3550  2022.1.23     NaN          NaN    1.0260   1.0260   1.0260  1.0260
# 3551  2022.1.30     NaN          NaN    1.2001   1.1961   1.2001  1.1961
# 3552   2022.2.6     NaN          NaN    1.3220   1.3280   1.3280  1.3220
# 3553  2022.2.27     NaN          NaN    1.4881   1.4940   1.4980  1.4881
# 3554   2022.3.6     NaN          NaN    1.4277   1.4437   1.4437  1.4277
#
#       Y2_Change
# 0       -0.0066
# 1        0.0333
# 2        0.1401
# 3       -0.0438
# ...

# %%
df_year10 = pd.read_csv("10year_bond.csv")

# %%
df_year10
# Out:
#            Date  Price   Open   High    Low  Change %
# 0      2011.1.3  3.334  3.334  3.334  3.334    0.0140
# 1      2011.1.4  3.338  3.338  3.338  3.338    0.0012
# 2      2011.1.5  3.463  3.463  3.463  3.463    0.0374
# 3      2011.1.6  3.399  3.399  3.399  3.399   -0.0185
# 4      2011.1.7  3.328  3.328  3.328  3.328   -0.0209
# ...         ...    ...    ...    ...    ...       ...
# 3310   2022.3.7  1.777  1.683  1.806  1.668    0.0557
# 3311   2022.3.8  1.840  1.773  1.878  1.758    0.0358
# 3312   2022.3.9  1.951  1.865  1.957  1.837    0.0603
# 3313  2022.3.10  1.993  1.951  2.021  1.911    0.0215
# 3314  2022.3.11  1.983  1.979  1.985  1.964   -0.0053
#
# [3315 rows x 6 columns]

# %%
df_year10.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Change %'], dtype='object')

# %%
df_year10.columns = ["Date", "Y10_Price", "Y10_Open", 'Y10_High', 'Y10_Low', 'Y10_Change']

# %%
df_total = pd.merge(df_total, df_year10, on = "Date", how = "outer")

# %%
df_total
# Out:
#             Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0       2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1       2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2       2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3       2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4       2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...          ...     ...          ...       ...      ...      ...     ...
# 3555   2011.2.21     NaN          NaN       NaN      NaN      NaN     NaN
# 3556  2011.11.24     NaN          NaN       NaN      NaN      NaN     NaN
# 3557   2012.1.16     NaN          NaN       NaN      NaN      NaN     NaN
# 3558   2012.2.20     NaN          NaN       NaN      NaN      NaN     NaN
# 3559   2017.7.23     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  Y10_High  Y10_Low  Y10_Change
# ...

# %%
df_us_cn = pd.read_csv("us_cn.csv")

# %%
df_us_cn
# Out:
#       Unnamed: 0       Date  UC_Price  UC_Open  UC_High  UC_Low  UC_Change
# 0           2902   2011.1.3    6.5898   6.5896   6.5898  6.5896    -0.0001
# 1           2901   2011.1.4    6.6070   6.5900   6.6123  6.5900     0.0026
# 2           2900   2011.1.5    6.6193   6.6071   6.6261  6.6089     0.0019
# 3           2899   2011.1.6    6.6263   6.6229   6.6269  6.6198     0.0011
# 4           2898   2011.1.7    6.6282   6.6251   6.6330  6.6251     0.0003
# ...          ...        ...       ...      ...      ...     ...        ...
# 2898           4   2022.3.7    6.3194   6.3258   6.3263  6.3158     0.0001
# 2899           3   2022.3.8    6.3178   6.3162   6.3214  6.3095    -0.0003
# 2900           2   2022.3.9    6.3174   6.3174   6.3286  6.3123    -0.0001
# 2901           1  2022.3.10    6.3212   6.3169   6.3264  6.3151     0.0006
# 2902           0  2022.3.11    6.3218   6.3219   6.3265  6.3209     0.0001
#
# [2903 rows x 7 columns]

# %%
df_us_cn = df_us_cn.drop(['Unnamed: 0'], axis=1)

# %%
df_total = pd.merge(df_total, df_us_cn, on = "Date", how = "outer")

# %%
df_total
# Out:
#             Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0       2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1       2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2       2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3       2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4       2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...          ...     ...          ...       ...      ...      ...     ...
# 3562  2015.12.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3563    2016.1.1     NaN          NaN       NaN      NaN      NaN     NaN
# 3564   2016.3.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3565   2017.4.14     NaN          NaN       NaN      NaN      NaN     NaN
# 3566   2018.3.30     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  Y10_High  Y10_Low  Y10_Change  UC_Price  \
# ...

# %%
df_us_eu = pd.read_csv("us_eu.csv")
df_us_eu = df_us_eu.drop(['Unnamed: 0'], axis=1)
df_us_eu.columns
df_us_eu.columns = ["Date", "EU_Price", "EU_Open", 'EU_High', 'EU_Low', 'EU_Change']
df_total = pd.merge(df_total, df_us_eu, on = "Date", how = "outer")
df_total
# Out:
#             Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0       2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1       2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2       2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3       2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4       2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...          ...     ...          ...       ...      ...      ...     ...
# 3562  2015.12.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3563    2016.1.1     NaN          NaN       NaN      NaN      NaN     NaN
# 3564   2016.3.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3565   2017.4.14     NaN          NaN       NaN      NaN      NaN     NaN
# 3566   2018.3.30     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  UC_Price  UC_Open  UC_High  UC_Low  \
# ...

# %%
df_us_gb = pd.read_csv("us_gb.csv")
df_us_gb = df_us_gb.drop(['Unnamed: 0'], axis=1)
df_us_gb.columns
df_us_gb.columns = ["Date", "GB_Price", "GB_Open", 'GB_High', 'GB_Low', 'GB_Change']
df_total = pd.merge(df_total, df_us_gb, on = "Date", how = "outer")
df_total
# Out:
#             Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0       2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1       2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2       2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3       2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4       2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...          ...     ...          ...       ...      ...      ...     ...
# 3562  2015.12.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3563    2016.1.1     NaN          NaN       NaN      NaN      NaN     NaN
# 3564   2016.3.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3565   2017.4.14     NaN          NaN       NaN      NaN      NaN     NaN
# 3566   2018.3.30     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  EU_Price  EU_Open  EU_High  EU_Low  \
# ...

# %%
df_us_jp = pd.read_csv("us_jp.csv")
df_us_jp = df_us_jp.drop(['Unnamed: 0'], axis=1)
df_us_jp.columns
df_us_jp.columns = ["Date", "JP_Price", "JP_Open", 'JP_High', 'JP_Low', 'JP_Change']
df_total = pd.merge(df_total, df_us_jp, on = "Date", how = "outer")
df_total
# Out:
#             Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0       2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1       2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2       2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3       2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4       2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...          ...     ...          ...       ...      ...      ...     ...
# 3562  2015.12.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3563    2016.1.1     NaN          NaN       NaN      NaN      NaN     NaN
# 3564   2016.3.25     NaN          NaN       NaN      NaN      NaN     NaN
# 3565   2017.4.14     NaN          NaN       NaN      NaN      NaN     NaN
# 3566   2018.3.30     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  GB_Price  GB_Open  GB_High  GB_Low  \
# ...

# %%
df_energy = pd.read_csv("total energy.csv")

# %%
df_energy
# Out:
#             Date  WTI_Price  WTI_Open  WTI_High  WTI_Low WTI_Change  B_Price  \
# 0       2011.1.4      89.38     91.50     92.07    88.36     -2.37%    93.53
# 1       2011.1.5      90.30     89.29     90.84    88.10      1.03%    95.50
# 2       2011.1.6      88.38     90.47     90.71    87.85     -2.13%    94.52
# 3       2011.1.7      88.03     88.18     89.48    87.25     -0.40%    93.33
# 4      2011.1.10      89.25     89.00     89.98    88.13      1.39%    95.70
# ...          ...        ...       ...       ...      ...        ...      ...
# 2931   2011.5.30        NaN       NaN       NaN      NaN        NaN   114.68
# 2932   2011.4.22        NaN       NaN       NaN      NaN        NaN      NaN
# 2933  2011.12.26        NaN       NaN       NaN      NaN        NaN      NaN
# 2934    2012.1.2        NaN       NaN       NaN      NaN        NaN      NaN
# 2935    2013.1.1        NaN       NaN       NaN      NaN        NaN      NaN
#
# ...

# %%
df_total = pd.merge(df_total, df_energy, on = "Date", how = "outer")
df_total
# Out:
#            Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0      2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1      2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2      2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3      2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4      2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...         ...     ...          ...       ...      ...      ...     ...
# 3582  2021.1.17     NaN          NaN       NaN      NaN      NaN     NaN
# 3583   2021.7.4     NaN          NaN       NaN      NaN      NaN     NaN
# 3584   2021.9.5     NaN          NaN       NaN      NaN      NaN     NaN
# 3585  2022.1.16     NaN          NaN       NaN      NaN      NaN     NaN
# 3586  2022.2.20     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  Gas_Price  Gas_Open  Gas_High  \
# ...

# %%
NAV_dollar_index = pd.read_csv('NAV_dollar_index.csv')

# %%
NAV_dollar_index
# Out:
#            Date    NAV  Dollor_Price  Dollor_Open  Dollor_High  Dollor_Low  \
# 0      2011.1.4  31.64         79.44        79.09        79.51       78.89
# 1      2011.1.5  31.91         80.26        79.40        80.35       79.34
# 2      2011.1.6  31.57         80.79        80.19        80.94       80.15
# 3      2011.1.7  31.65         81.01        80.87        81.14       80.69
# 4     2011.1.10  31.88         80.88        81.16        81.31       80.81
# ...         ...    ...           ...          ...          ...         ...
# 5542   2022.3.5  21.85           NaN          NaN          NaN         NaN
# 5543   2022.3.6  21.85           NaN          NaN          NaN         NaN
# 5544  2022.3.11  21.84         99.12        98.36        99.16       98.27
# 5545  2022.3.12  21.84           NaN          NaN          NaN         NaN
# 5546  2022.3.13  21.84           NaN          NaN          NaN         NaN
#
#       Dollor_Change %
# 0                0.39
# ...

# %%
df_total = pd.merge(df_total, NAV_dollar_index, on = "Date", how = "outer")
df_total
# Out:
#            Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0      2011.1.3  805.25          NaN     0.601    0.601    0.601   0.601
# 1      2011.1.4     788          NaN     0.621    0.621    0.621   0.621
# 2      2011.1.5  809.88          NaN     0.708    0.708    0.708   0.708
# 3      2011.1.6  788.13          NaN     0.677    0.677    0.677   0.677
# 4      2011.1.7  772.13          NaN     0.597    0.597    0.597   0.597
# ...         ...     ...          ...       ...      ...      ...     ...
# 5607  2022.2.13     NaN          NaN       NaN      NaN      NaN     NaN
# 5608  2022.2.19     NaN          NaN       NaN      NaN      NaN     NaN
# 5609  2022.2.26     NaN          NaN       NaN      NaN      NaN     NaN
# 5610   2022.3.5     NaN          NaN       NaN      NaN      NaN     NaN
# 5611  2022.3.12     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  heating_Open  heating_High  \
# ...

# %%
after_total = df_total.dropna(axis=0)

# %%
after_total
# Out:
#            Date     Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 436    2012.7.5       828     1,138.00    0.2890    0.289    0.289   0.289
# 437    2012.7.6    807.13     1,157.00    0.2740    0.274    0.274   0.274
# 439    2012.7.9    817.75     1,162.00    0.2660    0.266    0.266   0.266
# 440   2012.7.10     822.5     1,160.00    0.2700    0.270    0.270   0.270
# 441   2012.7.11    829.38     1,146.00    0.2660    0.266    0.266   0.266
# ...         ...       ...          ...       ...      ...      ...     ...
# 2946   2022.3.4  1,348.00     2,148.00    1.4899    1.552    1.554   1.412
# 2947   2022.3.7  1,425.25     2,235.00    1.5563    1.426    1.564   1.422
# 2948   2022.3.8  1,273.00     2,352.00    1.6008    1.554    1.641   1.552
# 2949   2022.3.9  1,199.50     2,558.00    1.6757    1.615    1.688   1.593
# 2950  2022.3.10  1,073.75     2,704.00    1.7024    1.682    1.735   1.650
#
# ...

# %%
after_total['Date'] = pd.to_datetime(after_total['Date'])
# Out:
# /var/folders/7n/qbcvswc55hzd4lnphhs0grb40000gn/T/ipykernel_8677/567566562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_total['Date'] = pd.to_datetime(after_total['Date'])

# %%
after_total.to_csv("final_raw_total(not_UN).csv", encoding="utf-8")

# %%
df_comtrade_un = pd.read_excel("Trade_NetWeight_flow_final.xlsx")
df_comtrade_un.columns
# Out:
# Index(['Date', 'NetWeight', 'TradeValue'], dtype='object')

# %%
df_total = after_total

# %%
df_total = pd.merge(df_total, df_comtrade_un, on = "Date", how = "outer")
df_total
# Out:
#            Date   Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0    2012-07-05     828     1,138.00     0.289    0.289    0.289   0.289
# 1    2012-07-06  807.13     1,157.00     0.274    0.274    0.274   0.274
# 2    2012-07-09  817.75     1,162.00     0.266    0.266    0.266   0.266
# 3    2012-07-10   822.5     1,160.00     0.270    0.270    0.270   0.270
# 4    2012-07-11  829.38     1,146.00     0.266    0.266    0.266   0.266
# ...         ...     ...          ...       ...      ...      ...     ...
# 3768 2022-04-26     NaN          NaN       NaN      NaN      NaN     NaN
# 3769 2022-04-27     NaN          NaN       NaN      NaN      NaN     NaN
# 3770 2022-04-28     NaN          NaN       NaN      NaN      NaN     NaN
# 3771 2022-04-29     NaN          NaN       NaN      NaN      NaN     NaN
# 3772 2022-04-30     NaN          NaN       NaN      NaN      NaN     NaN
#
#       Y2_Change  Y10_Price  Y10_Open  ...  heating_Low  heating_Change %  \
# ...

# %%
after_total = df_total.dropna(axis=0)

# %%
after_total
# Out:
#            Date     Price Baltic_Price  Y2_Price  Y2_Open  Y2_High  Y2_Low  \
# 0    2012-07-05       828     1,138.00    0.2890    0.289    0.289   0.289
# 1    2012-07-06    807.13     1,157.00    0.2740    0.274    0.274   0.274
# 2    2012-07-09    817.75     1,162.00    0.2660    0.266    0.266   0.266
# 3    2012-07-10     822.5     1,160.00    0.2700    0.270    0.270   0.270
# 4    2012-07-11    829.38     1,146.00    0.2660    0.266    0.266   0.266
# ...         ...       ...          ...       ...      ...      ...     ...
# 2358 2022-03-04  1,348.00     2,148.00    1.4899    1.552    1.554   1.412
# 2359 2022-03-07  1,425.25     2,235.00    1.5563    1.426    1.564   1.422
# 2360 2022-03-08  1,273.00     2,352.00    1.6008    1.554    1.641   1.552
# 2361 2022-03-09  1,199.50     2,558.00    1.6757    1.615    1.688   1.593
# 2362 2022-03-10  1,073.75     2,704.00    1.7024    1.682    1.735   1.650
#
# ...

# %%
after_total.to_csv("temp_DB1.csv", encoding="utf-8")

# %%
df = pd.read_csv('')

# %%
after_total["Date"] = pd.to_datetime(after_total["Date"])

# %%
after_total["Date"] = after_total["Date"].dt.strftime("%Y-%m-%d")

# %%
after_total
# Out:
#             Date    Price     Open     High      Low  Change %  Y2_Price  \
# 0     2011-01-04  25120.0  25120.0  25120.0  25120.0    0.0164    0.6210
# 1     2011-01-05  24720.0  24720.0  24720.0  24720.0   -0.0159    0.7080
# 2     2011-01-06  24534.0  24534.0  24534.0  24534.0   -0.0075    0.6770
# 3     2011-01-07  24180.0  24180.0  24180.0  24180.0   -0.0144    0.5970
# 4     2011-01-10  23847.0  23847.0  23847.0  23847.0   -0.0138    0.5730
# ...          ...      ...      ...      ...      ...       ...       ...
# 2700  2021-12-22  19951.0  19900.0  19850.0  19855.0    0.0171    0.6647
# 2701  2021-12-23  20021.0  20050.0  20040.0  20050.0    0.0035    0.6914
# 2702  2021-12-29  20383.0  20230.0  20200.0  20215.0    0.0169    0.7520
# 2703  2021-12-30  20587.0  20525.0  20490.0  20500.0    0.0100    0.7303
# 2704  2021-12-31  20757.0  20800.0  20750.0  20750.0    0.0083    0.7341
#
#       Y2_Open  Y2_High  Y2_Low  ...  Dollor_Change %_x  Dollor_Price_y  \
# ...

# %%
after_total = pd.read_csv("final_total1.csv")

# %%
after_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2705 entries, 0 to 2704
# Data columns (total 83 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2705 non-null   object
#  1   Price              2705 non-null   float64
#  2   Open               2705 non-null   float64
#  3   High               2705 non-null   float64
#  4   Low                2705 non-null   float64
#  5   Change %           2705 non-null   float64
#  6   Y2_Price           2705 non-null   float64
#  7   Y2_Open            2705 non-null   float64
#  8   Y2_High            2705 non-null   float64
#  9   Y2_Low             2705 non-null   float64
#  10  Y2_Change          2705 non-null   float64
#  11  Y10_Price          2705 non-null   float64
#  12  Y10_Open           2705 non-null   float64
#  13  Y10_High           2705 non-null   float64
#  14  Y10_Low            2705 non-null   float64
# ...

# %%
df_STS = pd.read_csv('STS_Price.csv')

# %%
df = pd.read_csv('final_raw_total.csv')

# %%
df_STS
# Out:
#             Date  STS_price
# 0     2011-01-01      100.7
# 1     2011-01-02      100.7
# 2     2011-01-03      100.7
# 3     2011-01-04      100.7
# 4     2011-01-05      100.7
# ...          ...        ...
# 4103  2022-03-27        NaN
# 4104  2022-03-28        NaN
# 4105  2022-03-29        NaN
# 4106  2022-03-30        NaN
# 4107  2022-03-31        NaN
#
# [4108 rows x 2 columns]

# %%
df
# Out:
#             Date      Price       Open       High        Low  Change %  \
# 0     2011-01-04  25,120.00  25,120.00  25,120.00  25,120.00    0.0164
# 1     2011-01-05  24,720.00  24,720.00  24,720.00  24,720.00   -0.0159
# 2     2011-01-06  24,534.00  24,534.00  24,534.00  24,534.00   -0.0075
# 3     2011-01-07  24,180.00  24,180.00  24,180.00  24,180.00   -0.0144
# 4     2011-01-10  23,847.00  23,847.00  23,847.00  23,847.00   -0.0138
# ...          ...        ...        ...        ...        ...       ...
# 5542  2010-12-29        NaN        NaN        NaN        NaN       NaN
# 5543  2010-12-30        NaN        NaN        NaN        NaN       NaN
# 5544  2010-12-31        NaN        NaN        NaN        NaN       NaN
# 5545  2022-03-12        NaN        NaN        NaN        NaN       NaN
# 5546  2022-03-13        NaN        NaN        NaN        NaN       NaN
#
#       Y2_Price  Y2_Open  Y2_High  Y2_Low  ...  Dollor_Change %_x  \
# ...

# %%
raw_df = pd.merge(df, df_STS, on = "Date", how = "outer")

# %%
raw_df
# Out:
#             Date      Price       Open       High        Low  Change %  \
# 0     2011-01-04  25,120.00  25,120.00  25,120.00  25,120.00    0.0164
# 1     2011-01-05  24,720.00  24,720.00  24,720.00  24,720.00   -0.0159
# 2     2011-01-06  24,534.00  24,534.00  24,534.00  24,534.00   -0.0075
# 3     2011-01-07  24,180.00  24,180.00  24,180.00  24,180.00   -0.0144
# 4     2011-01-10  23,847.00  23,847.00  23,847.00  23,847.00   -0.0138
# ...          ...        ...        ...        ...        ...       ...
# 5560  2022-03-27        NaN        NaN        NaN        NaN       NaN
# 5561  2022-03-28        NaN        NaN        NaN        NaN       NaN
# 5562  2022-03-29        NaN        NaN        NaN        NaN       NaN
# 5563  2022-03-30        NaN        NaN        NaN        NaN       NaN
# 5564  2022-03-31        NaN        NaN        NaN        NaN       NaN
#
#       Y2_Price  Y2_Open  Y2_High  Y2_Low  ...  Dollor_Price_y  Dollor_Open_y  \
# ...

# %%
raw_df.to_csv('final_total2.csv')

# %%
raw_df = pd.read_csv('final_total3.csv')

# %%
raw_df["Date"] = pd.to_datetime(raw_df["Date"])

# %%
df = raw_df

# %%
df.to_csv('final_total3.csv')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792 entries, 0 to 2791
# Data columns (total 83 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2792 non-null   object
#  1   Price              2792 non-null   int64
#  2   Open               2792 non-null   int64
#  3   High               2792 non-null   int64
#  4   Low                2792 non-null   int64
#  5   Change %           2792 non-null   float64
#  6   Y2_Price           2772 non-null   float64
#  7   Y2_Open            2772 non-null   float64
#  8   Y2_High            2772 non-null   float64
#  9   Y2_Low             2772 non-null   float64
#  10  Y2_Change          2772 non-null   float64
#  11  Y10_Price          2778 non-null   float64
#  12  Y10_Open           2778 non-null   float64
#  13  Y10_High           2778 non-null   float64
#  14  Y10_Low            2778 non-null   float64
#  15  Y10_Change         2778 non-null   float64
# ...
